# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["figure.dpi"] = 144

# %%
data = pd.read_csv("C:/Users/abhi/Desktop/ARIMA_All/ARIMA_All/Train_Status.csv")

# %%
error = pd.read_csv("C:/Users/abhi/Desktop/ARIMA_All/ARIMA_All/final_results_RF.csv")
for i in data["Name of Stock"]:
        print("Running Plot generation for :"+i)
        try:
#             print("In try")
            stock_data = pd.read_csv("C:/Users/abhi/Desktop/ARIMA_All/ARIMA_All/results/"+i+"_results.csv")
            stock_data = stock_data.iloc[-50:,]
            mse = error.loc[error.Name==i].MSE.values[0]
            mape = error.loc[error.Name==i].MAPE.values[0]
            title_plot = "LSTM : RMSE :"+str(mse)+" / SMAPE :"+str(mape)
            ax = stock_data.plot(x="date", y=["open","close","outcome"], kind="line", rot=0,title=title_plot).get_figure()
            ax.savefig('C:/Users/abhi/Desktop/ARIMA_All/ARIMA_All/images_RF/'+i+"_all.jpg")
#             print(ax)
        except:
            continue
# Out:
# Running Plot generation for :AAPL
# Running Plot generation for :MSFT
# Running Plot generation for :AMZN
# Running Plot generation for :GOOGL
# Running Plot generation for :BRK.B
# Running Plot generation for :UNH
# Running Plot generation for :TSLA
# Running Plot generation for :GOOG
# Running Plot generation for :XOM
# Running Plot generation for :JNJ
# Running Plot generation for :JPM
# Running Plot generation for :NVDA
# Running Plot generation for :PG
# Running Plot generation for :V
# Running Plot generation for :CVX
# Running Plot generation for :HD
# Running Plot generation for :LLY
# Running Plot generation for :MA
# Running Plot generation for :BAC
# Running Plot generation for :PFE
# Running Plot generation for :ABBV
# ...
